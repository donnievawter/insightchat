# %% [markdown]
# # Output Notebook Test
#
# Tests various output types: images, errors, HTML.

# %%
# Cell with base64 encoded image output (matplotlib plot simulation)
# This is a minimal 1x1 red PNG as base64
import base64
from IPython.display import Image, display
display(Image(data=base64.b64decode('iVBORw0KGgoAAAANSUhEUgAAAAEAAAABCAYAAAAfFcSJAAAADUlEQVR42mP8z8DwHwAFBQIAX8jx0gAAAABJRU5ErkJggg==')))

# %%
# Cell with error output
1 / 0

# %%
# Cell with HTML output
from IPython.display import HTML
HTML('<div style="color: blue; font-weight: bold;">This is HTML output</div>')

# %%
# Cell with very long output (truncation test)
# Generates ~500 bytes of text
for i in range(20):
    print(f'Line {i}: This is a test of output truncation functionality')

# %% [markdown]
# ## Test Summary
#
# **Expected Rendering:**
# - Cell 1: Shows 1x1 red PNG image
# - Cell 2: Displays error with red styling and traceback
# - Cell 3: Renders blue HTML text
# - Cell 4: Shows 20 lines of stdout (no truncation at this size)
