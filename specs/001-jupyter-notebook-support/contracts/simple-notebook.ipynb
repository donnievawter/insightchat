# %% [markdown]
# # Simple Test Notebook
#
# This notebook tests **basic rendering** of markdown and code cells.
#
# ## Features Tested
#
# - Markdown cells with headers, bold, lists
# - Code cells with execution counts
# - Text output (stdout)
# - Unexecuted code cells (execution_count: null)

# %%
# Basic Python code
print('Hello from Jupyter Notebook!')
x = 42
print(f'The answer is {x}')

# %%
# Code with execute_result output
result = [i**2 for i in range(5)]
result

# %% [markdown]
# ## Unexecuted Cell Below
#
# This cell has never been run (execution_count is null).

# %%
# This cell is unexecuted
print('This will not show output')

# %% [markdown]
# ## Test Complete
#
# Expected behavior:
# - All markdown renders with HTML formatting
# - Code cells show execution count badges: `In [1]:`, `In [2]:`, `In [ ]:`
# - Outputs appear below code cells
# - Syntax highlighting for Python code
